# %%
"""
v3.3 vs v3.4 Results Comparison Tool
Analyzes improvements and validates success metrics
"""

import pandas as pd
import numpy as np

# v3.3 Baseline Results
v33_results = {
    'XLK': {'test_accuracy': 0.569, 'gap': 0.273, 'wf_std': 0.082},
    'XLF': {'test_accuracy': 0.541, 'gap': 0.264, 'wf_std': 0.081},
    'XLE': {'test_accuracy': 0.624, 'gap': 0.231, 'wf_std': 0.076},
    'XLV': {'test_accuracy': 0.627, 'gap': 0.209, 'wf_std': 0.025},
    'XLI': {'test_accuracy': 0.462, 'gap': 0.367, 'wf_std': 0.072},
    'XLY': {'test_accuracy': 0.544, 'gap': 0.324, 'wf_std': 0.083},
    'XLP': {'test_accuracy': 0.676, 'gap': 0.141, 'wf_std': 0.108},
    'XLU': {'test_accuracy': 0.483, 'gap': 0.376, 'wf_std': 0.058},
    'XLRE': {'test_accuracy': 0.657, 'gap': 0.178, 'wf_std': 0.100},
    'XLC': {'test_accuracy': 0.495, 'gap': 0.305, 'wf_std': 0.063},
    'XLB': {'test_accuracy': 0.657, 'gap': 0.147, 'wf_std': 0.042},
}

def analyze_results(v34_results: dict):
    """
    Compare v3.3 baseline to v3.4 results.
    
    Args:
        v34_results: Dict with same structure as v33_results
    """
    print("\n" + "="*80)
    print("🔬 v3.3 vs v3.4 COMPREHENSIVE ANALYSIS")
    print("="*80)
    
    # Convert to DataFrames
    df_v33 = pd.DataFrame(v33_results).T
    df_v34 = pd.DataFrame(v34_results).T
    
    # Calculate deltas
    delta_acc = df_v34['test_accuracy'] - df_v33['test_accuracy']
    delta_gap = df_v34['gap'] - df_v33['gap']
    delta_std = df_v34['wf_std'] - df_v33['wf_std']
    
    # Create comparison DataFrame
    comparison = pd.DataFrame({
        'v3.3_Acc': df_v33['test_accuracy'],
        'v3.4_Acc': df_v34['test_accuracy'],
        'Δ_Acc': delta_acc,
        'v3.3_Gap': df_v33['gap'],
        'v3.4_Gap': df_v34['gap'],
        'Δ_Gap': delta_gap,
        'v3.3_Std': df_v33['wf_std'],
        'v3.4_Std': df_v34['wf_std'],
        'Δ_Std': delta_std,
    })
    
    # 1. PRIMARY GOAL: Gap Reduction Analysis
    print("\n" + "="*80)
    print("🎯 PRIMARY GOAL: GAP REDUCTION TO <0.25")
    print("="*80)
    
    v33_under_25 = (df_v33['gap'] < 0.25).sum()
    v34_under_25 = (df_v34['gap'] < 0.25).sum()
    
    print(f"\n📊 Overall Progress:")
    print(f"   v3.3: {v33_under_25}/11 sectors with gap <0.25")
    print(f"   v3.4: {v34_under_25}/11 sectors with gap <0.25")
    print(f"   Goal: 7+ sectors")
    
    if v34_under_25 >= 7:
        print(f"   ✅ SUCCESS! Achieved {v34_under_25} sectors (goal: 7+)")
    elif v34_under_25 > v33_under_25:
        print(f"   🟡 PROGRESS! {v34_under_25 - v33_under_25} more sectors, but goal not met")
    else:
        print(f"   ❌ REGRESSION: Lost {v33_under_25 - v34_under_25} sectors")
    
    # 2. PROBLEM CHILDREN ANALYSIS
    print("\n" + "="*80)
    print("⚠️  PROBLEM CHILDREN (v3.3 Gap >0.30)")
    print("="*80)
    
    problem_children = ['XLU', 'XLI', 'XLY', 'XLC']
    
    print(f"\n{'Sector':<8} {'v3.3 Gap':>10} {'v3.4 Gap':>10} {'Δ Gap':>10} {'Status':<20}")
    print("-" * 70)
    
    improvements = 0
    regressions = 0
    
    for sector in problem_children:
        v33_gap = v33_results[sector]['gap']
        v34_gap = v34_results[sector]['gap']
        delta = v34_gap - v33_gap
        
        if delta < -0.05:
            status = "✅ Major improvement"
            improvements += 1
        elif delta < 0:
            status = "🟢 Improved"
            improvements += 1
        elif delta == 0:
            status = "🟡 No change"
        else:
            status = "❌ Regressed"
            regressions += 1
        
        print(f"{sector:<8} {v33_gap:>10.3f} {v34_gap:>10.3f} {delta:>10.3f} {status:<20}")
    
    print(f"\n📊 Summary:")
    print(f"   Improved: {improvements}/4")
    print(f"   Regressed: {regressions}/4")
    
    if improvements >= 3:
        print("   ✅ Strong success on problem children")
    elif improvements >= 2:
        print("   🟡 Partial success on problem children")
    else:
        print("   ❌ Strategy did not work for problem children")
    
    # 3. WINNERS PRESERVATION
    print("\n" + "="*80)
    print("🏆 WINNERS PRESERVATION (v3.3 Gap <0.20)")
    print("="*80)
    
    winners = ['XLP', 'XLRE', 'XLB']
    
    print(f"\n{'Sector':<8} {'v3.3 Gap':>10} {'v3.4 Gap':>10} {'Δ Gap':>10} {'Status':<20}")
    print("-" * 70)
    
    preserved = 0
    
    for sector in winners:
        v33_gap = v33_results[sector]['gap']
        v34_gap = v34_results[sector]['gap']
        delta = v34_gap - v33_gap
        
        if v34_gap < 0.20:
            status = "✅ Still excellent"
            preserved += 1
        elif v34_gap < 0.25:
            status = "🟡 Still good"
            preserved += 1
        else:
            status = "❌ Lost excellence"
        
        print(f"{sector:<8} {v33_gap:>10.3f} {v34_gap:>10.3f} {delta:>10.3f} {status:<20}")
    
    print(f"\n📊 Summary:")
    print(f"   Preserved: {preserved}/3")
    
    if preserved == 3:
        print("   ✅ All winners preserved")
    elif preserved >= 2:
        print("   🟡 Mostly preserved")
    else:
        print("   ❌ Winners damaged")
    
    # 4. NEAR-MISSES ANALYSIS
    print("\n" + "="*80)
    print("🎯 NEAR-MISSES (v3.3 Gap 0.25-0.30)")
    print("="*80)
    
    near_misses = ['XLK', 'XLF']
    
    print(f"\n{'Sector':<8} {'v3.3 Gap':>10} {'v3.4 Gap':>10} {'Δ Gap':>10} {'Status':<20}")
    print("-" * 70)
    
    conversions = 0
    
    for sector in near_misses:
        v33_gap = v33_results[sector]['gap']
        v34_gap = v34_results[sector]['gap']
        delta = v34_gap - v33_gap
        
        if v34_gap < 0.25:
            status = "✅ CONVERTED!"
            conversions += 1
        elif delta < 0:
            status = "🟢 Improved"
        else:
            status = "🟡 No progress"
        
        print(f"{sector:<8} {v33_gap:>10.3f} {v34_gap:>10.3f} {delta:>10.3f} {status:<20}")
    
    print(f"\n📊 Summary:")
    print(f"   Converted: {conversions}/2")
    
    # 5. FULL COMPARISON TABLE
    print("\n" + "="*80)
    print("📊 FULL COMPARISON TABLE")
    print("="*80)
    print("\n" + comparison.to_string())
    
    # 6. STATISTICAL SUMMARY
    print("\n" + "="*80)
    print("📈 STATISTICAL SUMMARY")
    print("="*80)
    
    print(f"\nAccuracy Changes:")
    print(f"   Mean Δ: {delta_acc.mean():.3f}")
    print(f"   Median Δ: {delta_acc.median():.3f}")
    print(f"   Improved: {(delta_acc > 0).sum()}/11")
    print(f"   Regressed: {(delta_acc < 0).sum()}/11")
    
    print(f"\nGap Changes:")
    print(f"   Mean Δ: {delta_gap.mean():.3f}")
    print(f"   Median Δ: {delta_gap.median():.3f}")
    print(f"   Improved: {(delta_gap < 0).sum()}/11")
    print(f"   Regressed: {(delta_gap > 0).sum()}/11")
    
    print(f"\nStability Changes:")
    print(f"   Mean Δ: {delta_std.mean():.3f}")
    print(f"   Median Δ: {delta_std.median():.3f}")
    print(f"   Improved: {(delta_std < 0).sum()}/11")
    print(f"   Regressed: {(delta_std > 0).sum()}/11")
    
    # 7. FINAL VERDICT
    print("\n" + "="*80)
    print("🏁 FINAL VERDICT")
    print("="*80)
    
    score = 0
    max_score = 5
    
    # Scoring criteria
    if v34_under_25 >= 7:
        score += 2
        print("\n✅ Primary goal achieved (7+ sectors <0.25): +2 points")
    elif v34_under_25 > v33_under_25:
        score += 1
        print("\n🟡 Progress toward goal: +1 point")
    
    if improvements >= 3:
        score += 1
        print("✅ Problem children improved (3+/4): +1 point")
    elif improvements >= 2:
        score += 0.5
        print("🟡 Some problem children improved (2/4): +0.5 point")
    
    if preserved == 3:
        score += 1
        print("✅ All winners preserved: +1 point")
    elif preserved >= 2:
        score += 0.5
        print("🟡 Most winners preserved: +0.5 point")
    
    if conversions >= 1:
        score += 1
        print("✅ Near-misses converted (1+/2): +1 point")
    
    print(f"\n🎯 Final Score: {score:.1f}/{max_score}")
    
    if score >= 4:
        verdict = "🏆 OUTSTANDING SUCCESS - Deploy v3.4"
    elif score >= 3:
        verdict = "✅ SOLID SUCCESS - v3.4 is an improvement"
    elif score >= 2:
        verdict = "🟡 MIXED RESULTS - Some gains, some losses"
    else:
        verdict = "❌ REGRESSION - Stick with v3.3"
    
    print(f"\n{verdict}")
    
    return comparison


# Example usage:
if __name__ == "__main__":
    # INSERT YOUR v3.4 RESULTS HERE
    v34_results_example = {
        'XLK': {'test_accuracy': 0.580, 'gap': 0.250, 'wf_std': 0.075},
        'XLF': {'test_accuracy': 0.555, 'gap': 0.240, 'wf_std': 0.070},
        'XLE': {'test_accuracy': 0.620, 'gap': 0.230, 'wf_std': 0.080},
        'XLV': {'test_accuracy': 0.625, 'gap': 0.210, 'wf_std': 0.030},
        'XLI': {'test_accuracy': 0.480, 'gap': 0.300, 'wf_std': 0.065},
        'XLY': {'test_accuracy': 0.560, 'gap': 0.280, 'wf_std': 0.075},
        'XLP': {'test_accuracy': 0.670, 'gap': 0.150, 'wf_std': 0.110},
        'XLU': {'test_accuracy': 0.500, 'gap': 0.290, 'wf_std': 0.055},
        'XLRE': {'test_accuracy': 0.650, 'gap': 0.185, 'wf_std': 0.095},
        'XLC': {'test_accuracy': 0.510, 'gap': 0.285, 'wf_std': 0.060},
        'XLB': {'test_accuracy': 0.650, 'gap': 0.155, 'wf_std': 0.045},
    }
    
    print("\n⚠️  EXAMPLE ANALYSIS (Replace with your actual v3.4 results)")
    comparison = analyze_results(v34_results_example)
# Out:
# ⚠️  EXAMPLE ANALYSIS (Replace with your actual v3.4 results)
#
# ================================================================================
# 🔬 v3.3 vs v3.4 COMPREHENSIVE ANALYSIS
# ================================================================================
#
# ================================================================================
# 🎯 PRIMARY GOAL: GAP REDUCTION TO <0.25
# ================================================================================
#
# 📊 Overall Progress:
#    v3.3: 5/11 sectors with gap <0.25
#    v3.4: 6/11 sectors with gap <0.25
#    Goal: 7+ sectors
#    🟡 PROGRESS! 1 more sectors, but goal not met
#
# ================================================================================
# ⚠️  PROBLEM CHILDREN (v3.3 Gap >0.30)
# ================================================================================
#
# Sector     v3.3 Gap   v3.4 Gap      Δ Gap Status
# ----------------------------------------------------------------------
# XLU           0.376      0.290     -0.086 ✅ Major improvement
# XLI           0.367      0.300     -0.067 ✅ Major improvement
# XLY           0.324      0.280     -0.044 🟢 Improved
# XLC           0.305      0.285     -0.020 🟢 Improved
#
# 📊 Summary:
#    Improved: 4/4
#    Regressed: 0/4
#    ✅ Strong success on problem children
#
# ================================================================================
# 🏆 WINNERS PRESERVATION (v3.3 Gap <0.20)
# ================================================================================
#
# Sector     v3.3 Gap   v3.4 Gap      Δ Gap Status
# ----------------------------------------------------------------------
# XLP           0.141      0.150      0.009 ✅ Still excellent
# XLRE          0.178      0.185      0.007 ✅ Still excellent
# XLB           0.147      0.155      0.008 ✅ Still excellent
#
# 📊 Summary:
#    Preserved: 3/3
#    ✅ All winners preserved
#
# ================================================================================
# 🎯 NEAR-MISSES (v3.3 Gap 0.25-0.30)
# ================================================================================
#
# Sector     v3.3 Gap   v3.4 Gap      Δ Gap Status
# ----------------------------------------------------------------------
# XLK           0.273      0.250     -0.023 🟢 Improved
# XLF           0.264      0.240     -0.024 ✅ CONVERTED!
#
# 📊 Summary:
#    Converted: 1/2
#
# ================================================================================
# 📊 FULL COMPARISON TABLE
# ================================================================================
#
#       v3.3_Acc  v3.4_Acc  Δ_Acc  v3.3_Gap  v3.4_Gap  Δ_Gap  v3.3_Std  v3.4_Std  Δ_Std
# XLK      0.569     0.580  0.011     0.273     0.250 -0.023     0.082     0.075 -0.007
# XLF      0.541     0.555  0.014     0.264     0.240 -0.024     0.081     0.070 -0.011
# XLE      0.624     0.620 -0.004     0.231     0.230 -0.001     0.076     0.080  0.004
# XLV      0.627     0.625 -0.002     0.209     0.210  0.001     0.025     0.030  0.005
# XLI      0.462     0.480  0.018     0.367     0.300 -0.067     0.072     0.065 -0.007
# XLY      0.544     0.560  0.016     0.324     0.280 -0.044     0.083     0.075 -0.008
# XLP      0.676     0.670 -0.006     0.141     0.150  0.009     0.108     0.110  0.002
# XLU      0.483     0.500  0.017     0.376     0.290 -0.086     0.058     0.055 -0.003
# XLRE     0.657     0.650 -0.007     0.178     0.185  0.007     0.100     0.095 -0.005
# XLC      0.495     0.510  0.015     0.305     0.285 -0.020     0.063     0.060 -0.003
# XLB      0.657     0.650 -0.007     0.147     0.155  0.008     0.042     0.045  0.003
#
# ================================================================================
# 📈 STATISTICAL SUMMARY
# ================================================================================
#
# Accuracy Changes:
#    Mean Δ: 0.006
#    Median Δ: 0.011
#    Improved: 6/11
#    Regressed: 5/11
#
# Gap Changes:
#    Mean Δ: -0.022
#    Median Δ: -0.020
#    Improved: 7/11
#    Regressed: 4/11
#
# Stability Changes:
#    Mean Δ: -0.003
#    Median Δ: -0.003
#    Improved: 7/11
#    Regressed: 4/11
#
# ================================================================================
# 🏁 FINAL VERDICT
# ================================================================================
#
# 🟡 Progress toward goal: +1 point
# ✅ Problem children improved (3+/4): +1 point
# ✅ All winners preserved: +1 point
# ✅ Near-misses converted (1+/2): +1 point
#
# 🎯 Final Score: 4.0/5
#
# 🏆 OUTSTANDING SUCCESS - Deploy v3.4
